# %%
# 데이콘 교육용 유튜브 강의및 코드 설명을 필사

# %% [markdown]
# 항상 데이터 분석을 할때는
# 나만의 순서를 가지는 것이 좋을듯....
#
# 1. EDA
# 2. 전처리
# 3. 모델링
#
# 순으로 기억해놓자 꼭!!!

# %% [markdown]
# ## EDA

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
train=pd.read_csv('C:/Users/inha/Desktop/따릉이/train.csv')

test=pd.read_csv('C:/Users/inha/Desktop/따릉이/test.csv')

submission=pd.read_csv('C:/Users/inha/Desktop/따릉이/submission.csv')

# %%
train.head()

#문자열을 숫자형으로 변환해주는건 필요없겠다는 것 파악
#문자열이 있다면 혹은 카테고리컬 데이터가 있다면 라벨인코더해주거나 해당 feature삭제하거나 등등 방법 고민
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# ...

# %%
test.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   0     7                  20.7                     0.0                 1.3
# 1   1    17                  30.0                     0.0                 5.4
# 2   2    13                  19.0                     1.0                 2.1
# 3   4     6                  22.5                     0.0                 2.5
# 4   5    22                  14.6                     1.0                 3.4
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               62.0                954.0           0.041           44.0
# 1               33.0               1590.0           0.061           49.0
# 2               95.0                193.0           0.020           36.0
# 3               60.0               1185.0           0.027           52.0
# 4               93.0                218.0           0.041           18.0
#
#    hour_bef_pm2.5
# 0            27.0
# 1            36.0
# ...

# %%
submission.head()
# Out:
#    id  count
# 0   0    NaN
# 1   1    NaN
# 2   2    NaN
# 3   4    NaN
# 4   5    NaN

# %%
train.shape, test.shape, submission.shape
# Out:
# ((1459, 11), (715, 10), (715, 2))

# %%
train.info() 

#결측치가 있다. 그렇다면 오류를 없애기 위해 결측값을 어떻게 처리할까???
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1459 non-null   int64
#  1   hour                    1459 non-null   int64
#  2   hour_bef_temperature    1457 non-null   float64
#  3   hour_bef_precipitation  1457 non-null   float64
#  4   hour_bef_windspeed      1450 non-null   float64
#  5   hour_bef_humidity       1457 non-null   float64
#  6   hour_bef_visibility     1457 non-null   float64
#  7   hour_bef_ozone          1383 non-null   float64
#  8   hour_bef_pm10           1369 non-null   float64
#  9   hour_bef_pm2.5          1342 non-null   float64
#  10  count                   1459 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 125.5 KB

# %%
train.describe()
# Out:
#                 id         hour  hour_bef_temperature  hour_bef_precipitation  \
# count  1459.000000  1459.000000           1457.000000             1457.000000
# mean   1105.914325    11.493489             16.717433                0.031572
# std     631.338681     6.922790              5.239150                0.174917
# min       3.000000     0.000000              3.100000                0.000000
# 25%     555.500000     5.500000             12.800000                0.000000
# 50%    1115.000000    11.000000             16.600000                0.000000
# 75%    1651.000000    17.500000             20.100000                0.000000
# max    2179.000000    23.000000             30.000000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count         1450.000000        1457.000000          1457.000000
# mean             2.479034          52.231297          1405.216884
# std              1.378265          20.370387           583.131708
# ...

# %%
train.groupby('hour').mean()['count'].plot()  #시간별 대여량 그래프... 와우!! 출퇴근 시간에 많이 타겠구나 하는 정보획득

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(train.groupby('hour').mean()['count'],'go-')

#격자선
plt.grid()
#제목
plt.title('count by hours',fontsize=15)
#x축
plt.xlabel('hour',fontsize=15)
#y축
plt.ylabel('count',fontsize=15)

#보조선
plt.axvline(8,color='r')
plt.axvline(18,color='r')

#텍스트 입력
plt.text(8,150, 'go work',fontsize=10)
plt.text(18,150, 'leave work',fontsize=10)

#사진저장
plt.savefig('picture.png')

# %%
train.corr()
# Out:
#                               id      hour  hour_bef_temperature  \
# id                      1.000000 -0.010901             -0.000029
# hour                   -0.010901  1.000000              0.407306
# hour_bef_temperature   -0.000029  0.407306              1.000000
# hour_bef_precipitation -0.056267  0.021646             -0.097056
# hour_bef_windspeed     -0.003353  0.462797              0.375618
# hour_bef_humidity      -0.017948 -0.329612             -0.496088
# hour_bef_visibility     0.008950  0.176491              0.197417
# hour_bef_ozone          0.055234  0.390188              0.541228
# hour_bef_pm10          -0.025510 -0.035907             -0.003830
# hour_bef_pm2.5          0.003545 -0.061229             -0.078665
# count                  -0.002131  0.626047              0.619404
#
#                         hour_bef_precipitation  hour_bef_windspeed  \
# id                                   -0.056267           -0.003353
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(train.corr(),annot=True,)

# %% [markdown]
# ## 전처리

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
train[train['hour_bef_temperature'] .isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0                   NaN                     NaN
# 1035  1553    18                   NaN                     NaN
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934                  NaN                NaN                  NaN
# 1035                 NaN                NaN                  NaN
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 934              NaN            NaN             NaN   39.0
# 1035             NaN            NaN             NaN    1.0

# %%
train.groupby('hour').mean()['hour_bef_temperature']
# Out:
# hour
# 0     14.788136
# 1     14.155738
# 2     13.747541
# 3     13.357377
# 4     13.001639
# 5     12.673770
# 6     12.377049
# 7     12.191803
# 8     12.600000
# 9     14.318033
# 10    16.242623
# 11    18.019672
# 12    19.457377
# 13    20.648333
# 14    21.234426
# 15    21.744262
# 16    22.015000
# 17    21.603333
# 18    20.926667
# 19    19.704918
# 20    18.191803
# 21    16.978333
# 22    16.063934
# 23    15.418033
# Name: hour_bef_temperature, dtype: float64

# %%
train.groupby('hour').mean()['hour_bef_temperature'].plot()
plt.axhline(train.groupby('hour').mean()['hour_bef_temperature'].mean())

# %%
train['hour_bef_temperature'].fillna({934:14.788136,
                                     1035:20.926667},inplace=True)

train.loc[[934,1035],:]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0             14.788136                     NaN
# 1035  1553    18             20.926667                     NaN
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934                  NaN                NaN                  NaN
# 1035                 NaN                NaN                  NaN
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 934              NaN            NaN             NaN   39.0
# 1035             NaN            NaN             NaN    1.0

# %%
train[train['hour_bef_windspeed'].isnull()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18      33    13             22.600000                     0.0
# 244    381     1             14.100000                     0.0
# 260    404     3             14.000000                     0.0
# 376    570     0             14.300000                     0.0
# 780   1196    20             16.500000                     0.0
# 934   1420     0             14.788136                     NaN
# 1035  1553    18             20.926667                     NaN
# 1138  1717    12             21.400000                     0.0
# 1229  1855     2             14.000000                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18                   NaN               41.0                987.0
# 244                  NaN               55.0               1992.0
# 260                  NaN               50.0               2000.0
# 376                  NaN               49.0               2000.0
# ...

# %%
train.groupby('hour').mean()['hour_bef_windspeed']
# Out:
# hour
# 0     1.965517
# 1     1.836667
# 2     1.633333
# 3     1.620000
# 4     1.409836
# 5     1.296721
# 6     1.331148
# 7     1.262295
# 8     1.632787
# 9     1.829508
# 10    2.122951
# 11    2.485246
# 12    2.766667
# 13    3.281356
# 14    3.522951
# 15    3.768852
# 16    3.820000
# 17    3.801667
# 18    3.838333
# 19    3.595082
# 20    3.278333
# 21    2.755000
# 22    2.498361
# 23    2.195082
# Name: hour_bef_windspeed, dtype: float64

# %%
plt.plot(train.groupby('hour').mean()['hour_bef_windspeed'],'o-')

plt.axhline(train.groupby('hour').mean()['hour_bef_windspeed'].mean())

# %%
train['hour_bef_windspeed'].fillna({18:3.281356,
                                  244:1.836667,
                                  260:1.620000,
                                  376:1.965517,
                                  780:3.278333,
                                  934:1.965517,
                                  1035: 3.838333,
                                  1138:2.766667,
                                  1229:1.633333
    
    
},inplace=True)

# %%
train.loc[[18,244,260,376,780,934,1035,1138,1229],:]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18      33    13             22.600000                     0.0
# 244    381     1             14.100000                     0.0
# 260    404     3             14.000000                     0.0
# 376    570     0             14.300000                     0.0
# 780   1196    20             16.500000                     0.0
# 934   1420     0             14.788136                     NaN
# 1035  1553    18             20.926667                     NaN
# 1138  1717    12             21.400000                     0.0
# 1229  1855     2             14.000000                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18              3.281356               41.0                987.0
# 244             1.836667               55.0               1992.0
# 260             1.620000               50.0               2000.0
# 376             1.965517               49.0               2000.0
# ...

# %%
test[test['hour_bef_temperature'].isnull()]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 653  1943    19                   NaN                     NaN
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 653                 NaN                NaN                  NaN
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 653             NaN            NaN             NaN

# %%
train.groupby('hour').mean()['hour_bef_temperature']
# Out:
# hour
# 0     14.788136
# 1     14.155738
# 2     13.747541
# 3     13.357377
# 4     13.001639
# 5     12.673770
# 6     12.377049
# 7     12.191803
# 8     12.600000
# 9     14.318033
# 10    16.242623
# 11    18.019672
# 12    19.457377
# 13    20.648333
# 14    21.234426
# 15    21.744262
# 16    22.015000
# 17    21.603333
# 18    20.926667
# 19    19.704918
# 20    18.191803
# 21    16.978333
# 22    16.063934
# 23    15.418033
# Name: hour_bef_temperature, dtype: float64

# %%
test['hour_bef_temperature'].fillna(19.704918,inplace=True)   #train 데이터셋의 값으로 대체함

# %%
test[test['hour_bef_windspeed'].isnull()]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 653  1943    19             19.704918                     NaN
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 653                 NaN                NaN                  NaN
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 653             NaN            NaN             NaN

# %%
test['hour_bef_windspeed'].fillna(3.595082,inplace=True)   #train 데이터셋의 값으로 대체함

# %% [markdown]
# ## 모델링

# %%
# x  -> model -> y

# %%
features=['hour','hour_bef_temperature','hour_bef_windspeed']

# %%
x_train=train[features]
y_train=train['count']

x_test=test[features]

# %%
x_train.shape
# Out:
# (1459, 3)

# %%
y_train.shape
# Out:
# (1459,)

# %%
x_test
# Out:
#      hour  hour_bef_temperature  hour_bef_windspeed
# 0       7                  20.7                 1.3
# 1      17                  30.0                 5.4
# 2      13                  19.0                 2.1
# 3       6                  22.5                 2.5
# 4      22                  14.6                 3.4
# ..    ...                   ...                 ...
# 710     1                  24.6                 2.4
# 711     1                  18.1                 1.0
# 712     9                  23.3                 2.3
# 713    16                  27.0                 1.6
# 714     8                  22.3                 1.0
#
# [715 rows x 3 columns]

# %%
model100=RandomForestRegressor(n_estimators=100,
                           n_jobs=-1,random_state=0,
                           )

model100_5=RandomForestRegressor(n_estimators=100,
                           n_jobs=-1,random_state=0,
                           max_depth=5)


model200=RandomForestRegressor(n_estimators=200,
                           n_jobs=-1,random_state=0,
                          )

# %%
model100.fit(x_train,y_train)
model100_5.fit(x_train,y_train)
model200.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=-1, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
ypred1=model100.predict(x_test)
ypred2=model100_5.predict(x_test)
ypred3=model200.predict(x_test)

# %%
submission['count']=ypred1
submission.to_csv('model100.csv',index=False)

# %%
submission['count']=ypred2
submission.to_csv('model100_5.csv',index=False)

# %%
submission['count']=ypred3
submission.to_csv('model200.csv',index=False)
